# %% [markdown]
# # Introduction to Data Science
#
# ## Prof. [Saharon Rosset](https://www.tau.ac.il/~saharon/)
#
# ### When: 2018-2019 Sem A., Mon. 10:00
#
# ### Where: Screiber 007

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

s = pd.Series([1,3,5,np.nan,6,8])

plt.figure()
s.plot()

# %%
df = pd.read_csv('../../datasets/test.csv')
print(df)
# Out:
#    x   y
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %% [markdown]
# # What is Data Science?

# %%
from IPython.display import display, Image
display(Image(filename='images/data_science_venn.png'))

# %% [markdown]
# # Some Latex
#
# $$\sigma(X)^2 = \frac{\sum\limits_{i=1}^N (X -\mu)^2}{N}$$

# %% [markdown]
# # Controling Font (won't appear in pdf)
#
# Changing <font color='red'>color</font> of font, <font size=5>size</font> and <font face="times">font</font>
