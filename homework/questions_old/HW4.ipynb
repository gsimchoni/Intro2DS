# %% [markdown]
# # HW4: Probablistic Thinking and Advanced Exploratory Data Analysis
#
# ## Probability
#
# 1. Which of the following is a legitimate probability function for $X$, a random variable receiving values from $n = 0$ to Infinity?
#
# a. $P(X = n) = 1 \space\forall n$
#
# b. $P(X = n) = \frac {(-1)^{n}k^{2n+1}}{\sin (k)(2n+1)!}$ where $k$ is some parameter
#
# c. $P(X = n) = \frac {6}{\pi ^2 n^2}$
#
# d. $P(X = n) = \frac {k^n}{e^nn!}$ where $k$ is some parameter > 0
#
# <br>
#
# 2. Efrat built a classifier which can tell if a given image is of a cat, with 99% precision. I.e. $P(cat | classifier \space says \space cat) = 0.99$.
# Efrat's classifier's recall is 90%. I.e. $P(classifier \space says \space cat | cat) = 0.90$. Which of the following is correct regarding the prevalence of cats images in Efrat's data, i.e. $P(cat)$?
#
# a. We cannot calculate this probability and in fact it could be very low, lower than 1%
#
# b. Even if we knew it, we couldn't know the probability the classifer predicts cats, i.e. $P(classifier \space says \space cat)$
#
# c. We can calculate this probability
#
# d. If we knew it's lower than 1%, then we'd know that the probability the classifer predicts cats, i.e. $P(classifier \space says \space cat)$ is larger than 1%
#
# ## Discrete Distributions
#
# 3. In Oded's shop the number of Optimus Prime transformers sold every day, is Poisson distributed with an average of 2. On Sunday morning Oded notices he is left without Optimus Prime transformers! How many should he order so that probability of running out of Optimus Primes until next Sunday morning (i.e. exactly 7 days) is less than 5%? You can assume Oded's order will instantly arrive and please consider using `scipy.stats.poisson` for the final answer.
#
# a. 10
#
# b. 12
#
# c. 20
#
# d. 24
#
# <br>
#
# 4. It has been found that in a typical Researcher's academic life span, the number of experiments she would run is 100, with the probability of "reaching the wrong conclusion" of 0.01. What is the expected number of experiments "reaching the wrong conclusion" in a typical Researcher's academic life, and what is the probability that a typical Researcher would "reach the wrong conclusion" in at least 1 experiment during her academic life?
#
# a. 1 and 1, respectively
#
# b. 1 and 0.63, respectively
#
# c. 10 and 0.63, respectiverly
#
# d. 10 and 0.99, respectively
#
# ## Relation Between a Pair of Discrete Variables
#
# 5. A Web Analyst has tested 3 different versions of a website, each seen by a different amount of users. For each version, for each user, the Analyst knows whether the user has signed up for the website or not. He put the results in a contingency table:
#
# |  Version/Sign | Yes  | No|
# |-----|--------|---------|
# | V1   |   1000    |   3000     |
# | V2   |   400    |   100  |
# | V3   |   900 |   2700  |
#
# What is the probability a user seeing V2 will not sign up to the website?
#
# a. 0.20
#
# b. 0.25
#
# c. 0.33
#
# d. 0.8
#
# <br>
#
# 6. Which of the following is correct?
#
# a. A user signing up to the website is 2.5 more likely to have seen V3 of the website, than V2.
#
# b. A user who has seen V1 is 2.5 more likely to sign up to the website, than a user who has seen V2.
#
# c. A user who has seen V2 is 3.2 more likely to sign up to the website, than a user who has seen V1.
#
# d. A user not signing up to the website has 10% more chance to have seen V1, than V3.
#
# ## PCA
#
# 7. Which of the following is correct?
#
# a. Before performing PCA, it is necessary to scale `X` so that each column has standard deviation of 1.
#
#
# b. PCA cannot be performed if the data contains categorical features.
#
# c. The sum of the eigenvalues of covariance matrix $X^TX$ once `X` has been centered, is equal to the sum of variances of all `X` columns.
#
# d. PCA cannot be performed if $n$ number of observations is smaller than $p$ number of features.
