# %% [markdown]
# # HW 1: Refreshers & Introduction
#
#
# ## Basic definitions
# 1.	Which of the following is not primarily a data science project:
#
# a.	Collect and analyze data from a linear accelerator, looking for a new particle
#
# b.	Build a robot which serves cocktail drinks
#
# c.	Given two website designs, test which one attracts more traffic
#
# d.	Do an online poll to predict the outcome of an election
#
#
# We mentioned in class that data science has three interweaved components: Computing expertise, statistical expertise, domain expertise (Physics). Consider the following tasks involved in a hypothetical data science project to find a new particle:
#
# a.	Designing the database to hold results
#
# b.	Deciding which signals should be collected, and what kind of signals we are looking for to identify a new particle
#
# c.	Fitting regression models to the data and performing statistical tests in search of the signals
#
# d.  Recruiting the right personnel to carry out the project
#
# 2. Which one of the above most clearly belongs to the statistical expertise category?
# 3. Which one most clearly belongs to the computing expertise category?
# 4. Which one most clearly belongs to the deomain expertise category?
#
# ## Algebra refresher
#
# 1. Given column vector x of length n, what kind of object is xxt  and what is its rank?
#
# a. n*n matrix, rank can be between 1 and n
#
# b. n*1 matrix (a vector), rank is 1
#
# c. n*n, matrix, rank is 1
#
# d. 1*1 matrix (a scalar), rank is 1
#
#
# 2. Given an n*n matrix, what conditions are required for it to be invertible
#
# a. That it is full rank, and the main diagonal elements are not 0
#
# b. That all its main diagonal elements are not 0
#
# c. That it is full rank
#
# d. That its main diagonal is all ones
#
# ## Infi refresher
#
# 3. For the function f(x) = (x-2)2, we calculate its first-order Taylor expansion around the point x=2. What is the value of this expansion at x=4?
#
# a. 0
#
# b. 4
#
# c. 2
#
# d. 1
#
# 4. Using l'Hospital's rule, what is the limit of x2/(ex-1) as x->0 from above?
#
# a. 0
#
# b. 1
#
# c. Infinity
#
# d. Cannot be calculated
#
#
# ## Probability refresher
#
# 5. X,Y are random variables, which of the following is true:
#
# a. E(X+Y) = E(X) + E(Y), E(XY) = E(X)E(Y)
#
# b. Var(X+Y) = Var(X) + Var(Y) if X,Y are independent
#
# c. Var(X+Y) = Var(X) + Var(X) + Cov(X,Y)
#
# d. Both i and iii
#
# 6. We have a fair coin, and we define a random variable that is equal 1 if heads come up and 0 if tails. What kind of distribution do the outcome of a single flip and the sum of outcomes of 10 flips have?
#
# a. Uniform(0,1) and Bernoulli(1), respectively
#
# b. Poisson(1) and Poisson(10), respectively
#
# c. Bernoulli(1) and Bernoulli(10), respectively
#
# d. Bernoulli(0.5) and Binomial(10,0.5), respectively
#
# 7. I am throwing a fair dice twice, what is the conditional probability that the first throw gives 1, GIVEN that the sum of the throws is 3?
#
# a. 1/2
#
# b. 1
#
# c. 1/6
#
# d. 1/3
#
# 8. In the same situation, what is the probability that the sum is 3 AND the first throw gives 1?
#
# a. 1/6
#
# b. 1/36
#
# c. 1/18
#
# d. 1/4
#
#
#
# ## Python Basics
#
# 1. Which one of the following List Comprehensions would create a list containing all prime numbers under 100?
#
# a. `[possiblePrime for possiblePrime in range(2, 100) for num in range(2, possiblePrime) if possiblePrime % num != 0]`
#
# b. `[possiblePrime for possiblePrime in range(2, 100) if all(possiblePrime % num != 0 for num in range(2, possiblePrime))]`
#
# c. `list({possiblePrime for possiblePrime in range(2, 100) for num in range(2, possiblePrime) if possiblePrime % num == 0})`
#
# d. `{i: possiblePrime for i, possiblePrime in enumerate(range(2, 100)) if all(possiblePrime % num != 0 for num in range(2, possiblePrime))}`
#
# <br>
#
# 2. See this right-aligned pyramid of the 0 to 9 digits:
#
# ```
#           0
#          01
#         012
#        0123
#       01234
#      012345
#     0123456
#    01234567
#   012345678
#  0123456789
# ```
#
# The following program attempts to print the pyramid to screen:
#
# ```
# def print_pyramid():
#     s = ''
#     for i in range(10):
#         s += i
#         print(' ' * (9 - i), s)
# ```
#
# But there is a bug. Which of the following will fix the bug?
#
# a. Replace the 2nd statement with `for i in range(9):`
#
# b. Replace the 3rd statement with `s += str(i)`
#
# c. Replace the 4th statement with `print(' ' * (10 - i), s)`
#
# d. Both b and c
#
# <br>
#
# 3. See the following program:
#
# ```
# def does_something(l1, l2):
#     s = set()
#     for e1, e2 in zip(l1, l2):
#         if e1 == e2:
#             s.add(e1)
#     return s
# ```
#
# Which of the following is incorrect?
#
# a. The program will work on any two lists `l1` and `l2` (i.e. no exception thrown)
#
# b. The program will work on any two strings `l1` and `l2` (i.e. no exception thrown)
#
# c. The output of does_something('abc', 'abc') is the set `{'abc'}`
#
# d. The output of does_something(['abc'], ['abc']) is the set `{'abc'}`
#
# <br>
#
# 4. See the following program:
#
# ```
# x = 123
#
# def f1():
#     x = 124
#     return x
#
# print(f1())
# print(x)
# ```
#
# The output of this program is:
#
# ```
# 124
# 123
# ```
#
# Which of the following changes would make the output:
#
# ```
# 124
# 124
# ```
#
# a. Adding the argument `x` to the function defintion (i.e. `def f1(x)`), then calling `f1(x)` instead fo `f1()`
#
# b. Adding the statement `global x` before assigning `x = 123` at the beginning of the program
#
# c. Adding the statement `x = f1()` before printing `x` in the last line
#
# d. Adding the argument `x` to the function call (i.e. `print(f1(x))`)
#
#
# ## Numpy
#
# 5. What does the following statement do, from left to right? (assume `import numpy as np`)
#
# ```
# np.zeros((3, 3)) + 1 / np.array([1, 2, 3])
# ```
#
# a. It creates a 3x3 array of zeros, adds 1 to all values and divides each row elementwise by the row [1, 2, 3]
#
# b. It creates a 3x3 array of zeros, then throws an exception for trying to add a constant to a numpy array
#
# c. It takes a tuple (3,3), makes it (0,0), adds 1 to all values and divides each row elementwise by the row [1, 2, 3]
#
# d. It creates a 3x3 array of zeros, adds 1 to all values, then throws an exception for trying to divide a 3x3 array with a 1D arrray
#
# <br>
#
# 6. What will be the output of the following statement? (Make sure you understand why)
#
# ```
# np.array(range(10))[1:-2][::-3].sum()
# ```
#
# a. 12
#
# b. 15
#
# c. 20
#
# d. 28
#
# <br>
#
# 7. You have a 2D matrix `X1` of `n` observations x `p1` features. You have a 2D matrix `X2` of `n` observations x `p2` additional features. You would like to bind them side by side so that you would get the matrix `X3` of `n` observations x `p1 + p2` features. Which of the following would get you there?
#
# a. `np.hstack((X1, X2))`
#
# b. `np.concatenate((X1, X2))`
#
# c. `np.stack((X1, X2), axis=0)`
#
# d. `np.vstack((X1, X2))`
